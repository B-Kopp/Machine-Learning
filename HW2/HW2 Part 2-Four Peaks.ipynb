# %%
import mlrose
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
best_state = []
best_fitness = []
space = np.linspace(5,100,20)

for N in space:
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = N, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using random hill climbing
    state, fitness = mlrose.random_hill_climb(problem, max_attempts = 100, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    
plt.figure()
plt.suptitle("Four Peaks Randomized Hill Climbing Fitness Curve")
plt.title("No restarts, 5,000 iterations")
plt.xlabel("N")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
best_state = []
best_fitness = []
space = np.linspace(0,30,31)

for N in space:
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using random hill climbing
    state, fitness = mlrose.random_hill_climb(problem, max_attempts = 100, max_iters = 5000, restarts=int(N))
    best_state.append(state)
    best_fitness.append(fitness)
    
plt.figure()
plt.suptitle("Four Peaks Randomized Hill Climbing Fitness Curve")
plt.title("5,000 iterations, N=100")
plt.xlabel("Restarts")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
start = time.time()

fitness = mlrose.FourPeaks()
problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
# Set random seed
np.random.seed(1)
# Solve problem using random hill climbing
state, fitness, curve = mlrose.random_hill_climb(problem, max_attempts = 100, max_iters = 5000, restarts=16, curve=True)

end = time.time()

print("Random Hill Climbing Algorithm Time:", round(end - start,4))
print("Random Hill Climbing Algorithm Fitness Score:", fitness)
    
plt.figure()
plt.suptitle("Four Peaks Randomized Hill Climbing Fitness Curve")
plt.title("16 restarts, N=100")
plt.xlabel("Iterations")
plt.ylabel("Fitness")

plt.grid()
plt.plot(np.linspace(1,len(curve),len(curve)), curve)
plt.show()
# Out:
# Random Hill Climbing Algorithm Time: 0.2081
# Random Hill Climbing Algorithm Fitness Score: 20.0

# %%
best_state = []
best_fitness = []
space = np.linspace(5,100,20)

for N in space:
    # Define decay schedule
    schedule = mlrose.ExpDecay()
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = N, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using simulated annealing
    state, fitness = mlrose.simulated_annealing(problem, schedule=schedule, max_attempts = 100, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    
plt.figure()
plt.suptitle("Four Peaks Simulated Annealing Fitness Curve")
plt.title("Exponential Decay, 5,000 iterations")
plt.xlabel("N")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
best_state = []
best_fitness = []
space = [mlrose.ExpDecay(), mlrose.GeomDecay(), mlrose.ArithDecay()]

for N in space:
    # Define decay schedule
    schedule = N
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using simulated annealing
    state, fitness = mlrose.simulated_annealing(problem, schedule=schedule, max_attempts = 100, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    
names = ['ExpDecay', 'GeomDecay', 'ArithDecay']
y_pos = np.arange(len(names))
plt.figure()
plt.suptitle("Four Peaks Simulated Annealing Fitness Curve")
plt.title("N=100, 5,000 iterations")
plt.xlabel("Decay Schedule")
plt.ylabel("Fitness")
plt.xticks(y_pos, names)

plt.ylim(30,90)
plt.bar(y_pos, best_fitness, align='center', alpha=0.5)

plt.show()

# %%
start = time.time()

# Define decay schedule
schedule = mlrose.ExpDecay()
fitness = mlrose.FourPeaks()
problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
# Set random seed
np.random.seed(1)
# Solve problem using simulated annealing
state, fitness, curve = mlrose.simulated_annealing(problem, schedule=schedule, max_attempts = 100, max_iters = 5000, curve = True)

end = time.time()

print("Simulated Annealing Time:", round(end - start,4))
print("Simulated Annealing Fitness Score:", fitness)
    
plt.figure()
plt.suptitle("Four Peaks Simulated Annealing Fitness Curve")
plt.title("Exponential Decay, N=100")
plt.xlabel("Iterations")
plt.ylabel("Fitness")

plt.grid()
plt.plot(np.linspace(1,len(curve),len(curve)), curve)
plt.show()
# Out:
# Simulated Annealing Time: 0.6982
# Simulated Annealing Fitness Score: 78.0

# %%
best_state = []
best_fitness = []
space = np.linspace(5,100,20)

for N in space:
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = N, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using genetic algorithm
    state, fitness = mlrose.genetic_alg(problem, pop_size=150, mutation_prob=0.08, max_attempts = 10, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    
plt.figure()
plt.suptitle("Four Peaks Genetic Algorithm Fitness Curve")
plt.title("150 population size, 0.08 mutation probability, 100,000 iterations")
plt.xlabel("N")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
best_state = []
best_fitness = []
space = np.linspace(50,400,8)

for N in space:
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using genetic algorithm
    state, fitness = mlrose.genetic_alg(problem, pop_size=int(N), mutation_prob=0.08, max_attempts = 100, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    

plt.figure()
plt.suptitle("Four Peaks Genetic Algorithm Fitness Curve")
plt.title("100 N, 0.08 mutation probability, 5,000 iterations")
plt.xlabel("Population Size")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
best_state = []
best_fitness = []
space = np.linspace(0.02,0.16,8)

for N in space:
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using genetic algorithm
    state, fitness = mlrose.genetic_alg(problem, pop_size=150, mutation_prob=N, max_attempts = 100, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    

plt.figure()
plt.suptitle("Four Peaks Genetic Algorithm Fitness Curve")
plt.title("150 population size, N=100, 5,000 iterations")
plt.xlabel("Mutation Probability")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
start = time.time()

fitness = mlrose.FourPeaks()
problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
# Set random seed
np.random.seed(1)
# Solve problem using genetic algorithm
state, fitness, curve = mlrose.genetic_alg(problem, pop_size=150, mutation_prob=0.08, max_attempts = 100, max_iters = 5000, curve = True)

end = time.time()

print("Genetic Algorithm Time:", round(end - start,4))
print("Genetic Algorithm Fitness Score:", fitness)
    
plt.figure()
plt.suptitle("Four Peaks Genetic Algorithm Fitness Curve")
plt.title("150 population size, 0.08 mutation probability, 100 N")
plt.xlabel("Iterations")
plt.ylabel("Fitness")

# box-like grid
plt.grid()

plt.plot(np.linspace(1,len(curve),len(curve)), np.amax(curve,axis=1))

# sizes the window for readability and displays the plot
plt.show()
# Out:
# Genetic Algorithm Time: 12.6575
# Genetic Algorithm Fitness Score: 129.0

# %%
best_state = []
best_fitness = []
space = np.linspace(5,100,20)

for N in space:
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = N, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using mimic algorithm
    state, fitness = mlrose.mimic(problem, pop_size=400, keep_pct=0.35, max_attempts = 100, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    
plt.figure()
plt.suptitle("Four Peaks MIMIC Algorithm Fitness Curve")
plt.title("400 population size, 0.35 keep percentage, 5,000 iterations")
plt.xlabel("N")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
best_state = []
best_fitness = []
space = np.linspace(10,400,4)

for N in space:
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using mimic algorithm
    state, fitness = mlrose.mimic(problem, pop_size=int(N), keep_pct=0.35, max_attempts = 100, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    
plt.figure()
plt.suptitle("Four Peaks MIMIC Algorithm Fitness Curve")
plt.title("5,000 iterations, 0.35 keep percentage, N=100")
plt.xlabel("Population Size")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
best_state = []
best_fitness = []
space = np.linspace(0.05,0.35,4)

for N in space:
    fitness = mlrose.FourPeaks()
    problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
    # Set random seed
    np.random.seed(1)
    # Solve problem using mimic algorithm
    state, fitness = mlrose.mimic(problem, pop_size=400, keep_pct=N, max_attempts = 100, max_iters = 5000)
    best_state.append(state)
    best_fitness.append(fitness)
    
plt.figure()
plt.suptitle("Four Peaks MIMIC Algorithm Fitness Curve")
plt.title("5,000 iterations, 400 population size, N=100")
plt.xlabel("Keep Percentage")
plt.ylabel("Fitness")

plt.grid()
plt.plot(space, best_fitness)
plt.show()

# %%
start = time.time()

fitness = mlrose.FourPeaks()
problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
# Set random seed
np.random.seed(1)
# Solve problem using mimic algorithm
state, fitness, curve = mlrose.mimic(problem, pop_size=400, keep_pct=0.35, max_attempts = 100, max_iters = 5000, curve = True)

end = time.time()

print("MIMIC Algorithm Time:", round(end - start,4))
print("MIMIC Algorithm Fitness Score:", fitness)
    
plt.figure()
plt.suptitle("Four Peaks MIMIC Algorithm Fitness Curve")
plt.title("400 population size, 0.35 keep percentage, N=100")
plt.xlabel("Iterations")
plt.ylabel("Fitness")

plt.grid()
plt.plot(np.linspace(1,len(curve),len(curve)), np.amax(curve,axis=1))
plt.show()
# Out:
# MIMIC Algorithm Time: 1133.862
# MIMIC Algorithm Fitness Score: 129.0

# %%
fitness = mlrose.FourPeaks()
problem = mlrose.DiscreteOpt(length = 100, fitness_fn = fitness, maximize = True, max_val = 2)
# Set random seed
np.random.seed(1)
# Solve problem using random hill climbing
state_rhc, fitness_rhc, curve_rhc = mlrose.random_hill_climb(problem, max_attempts = 100, max_iters = 5000, restarts=16, curve=True)
np.random.seed(1)
state_sa, fitness_sa, curve_sa = mlrose.simulated_annealing(problem, schedule=mlrose.ExpDecay(), max_attempts = 100, max_iters = 5000, curve=True)
np.random.seed(1)
state_ga, fitness_ga, curve_ga = mlrose.genetic_alg(problem, pop_size=150, mutation_prob=0.08, max_attempts = 100, max_iters = 5000, curve=True)
np.random.seed(1)
state_mimic, fitness_mimic, curve_mimic = mlrose.mimic(problem, pop_size=400, keep_pct=0.35, max_attempts = 100, max_iters = 5000, curve=True)

# %%
plt.figure()
plt.title("Four Peaks Fitness")
plt.xlabel("Iterations (log scale)")
plt.ylabel("Fitness")

plt.grid()
plt.semilogx(np.linspace(1,len(curve_rhc),len(curve_rhc)), curve_rhc, label='RHC')
plt.semilogx(np.linspace(1,len(curve_sa),len(curve_sa)), curve_sa, label='SA')
plt.semilogx(np.linspace(1,len(curve_ga),len(curve_ga)), np.amax(curve_ga,axis=1), label='GA')
plt.semilogx(np.linspace(1,len(curve_mimic),len(curve_mimic)), np.amax(curve_mimic,axis=1), label='MIMIC')
plt.legend(loc='upper left')
plt.show()
